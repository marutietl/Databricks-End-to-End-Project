# %%
df=spark.read.table("databricks_ete_cata.bronze.regions")

# %%
df.display()

# %%
df=df.drop("_rescued_data")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .save("abfss://silver@databricksadlsete.dfs.core.windows.net/regions")

# %%
df=spark.read.format("delta")\
    .load("abfss://silver@databricksadlsete.dfs.core.windows.net/regions")\
    .display()

# %%
# %sql
CREATE TABLE IF NOT EXISTS databricks_ete_cata.silver.Regions_Silver
USING DELTA
LOCATION 'abfss://silver@databricksadlsete.dfs.core.windows.net/regions'

# %%
#%sql
#select * from databricks_ete_cata.silver.regions_silver
